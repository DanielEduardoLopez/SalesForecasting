# %% [markdown]
# # **Sales Prediction for AztraZeneca**
# ____

# %% [markdown]
# Author: **Daniel Eduardo López**
#
# <font size="-1"><a href="https://www.linkedin.com/in/daniel-eduardo-lopez">LinkedIn</a> | <a href="https://github.com/DanielEduardoLopez">GitHub </a></font>
#
# **17/11/2023**

# %% [markdown]
# ![sales-figures-1473495_450p.jpg](data:image/jpeg;base64,...)
#
#
# <font size="-1">Image Credit: <a href="https://www.freeimages.com/es/photo/sales-figures-1473495">wagg66</a> from <a href="https://www.freeimages.com">FreeImages</a></font>.

# %% [markdown]
# ___
# ## **Table of Contents**
# ___
#
# 1. [**Introduction**](#intro)<br>
#     1.1. [Background](#background)<br>
#     1.2. [General Objective](#objective)<br>
#     1.3. [Research Question](#question)<br>
#     1.4. [Hypothesis](#hypothesis)<br>
#     1.5. [Abridged Methodology](#methodology)<br>
#     1.6. [Notebook's Goal](#goal)<br>
# 2. [**Data Collection**](#collection)<br>

# %% [markdown]
# <a class="anchor" id="intro"></a>
# ___
# ## **1. Introduction**
# ___

# %% [markdown]
# ### **1.1 Background** <a class="anchor" id="intro"></a>
#
# In the ever-changing world of today, it is of the utmost importance to be able to quantify the impact of the external economic indicators in the revenue of an organization.
#
# In the context of Mexico, it is possible to collect public data from different government offices such as INEGI or BANXICO, or from international sources such as the S&P500.
#
# In this sense, the purpose of the present proyect is to predict several economic indicators over the next few years and, then, use them to predict later the sales of AstraZeneca.
